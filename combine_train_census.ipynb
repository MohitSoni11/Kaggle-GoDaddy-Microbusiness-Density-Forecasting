# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('data/train.csv', parse_dates=['first_day_of_month'])
census = pd.read_csv('data/census_starter.csv')

# %%
train.head()
# Out:
#             row_id  cfips          county    state first_day_of_month  \
# 0  1001_2019-08-01   1001  Autauga County  Alabama         2019-08-01
# 1  1001_2019-09-01   1001  Autauga County  Alabama         2019-09-01
# 2  1001_2019-10-01   1001  Autauga County  Alabama         2019-10-01
# 3  1001_2019-11-01   1001  Autauga County  Alabama         2019-11-01
# 4  1001_2019-12-01   1001  Autauga County  Alabama         2019-12-01
#
#    microbusiness_density  active
# 0               3.007682    1249
# 1               2.884870    1198
# 2               3.055843    1269
# 3               2.993233    1243
# 4               2.993233    1243

# %% [markdown]
# Let's separate the `first_day_of_month` column into month and year to make it easier to filter through the dataframe

# %%
# Adding month and year columns
train['month'] = train['first_day_of_month'].dt.month
train['year'] = train['first_day_of_month'].dt.year

# Removing first_day_of_month column
train.drop(['first_day_of_month'], axis=1, inplace=True)
train.head()
# Out:
#             row_id  cfips          county    state  microbusiness_density  \
# 0  1001_2019-08-01   1001  Autauga County  Alabama               3.007682
# 1  1001_2019-09-01   1001  Autauga County  Alabama               2.884870
# 2  1001_2019-10-01   1001  Autauga County  Alabama               3.055843
# 3  1001_2019-11-01   1001  Autauga County  Alabama               2.993233
# 4  1001_2019-12-01   1001  Autauga County  Alabama               2.993233
#
#    active  month  year
# 0    1249      8  2019
# 1    1198      9  2019
# 2    1269     10  2019
# 3    1243     11  2019
# 4    1243     12  2019

# %%
census.head()
# Out:
#    pct_bb_2017  pct_bb_2018  pct_bb_2019  pct_bb_2020  pct_bb_2021  cfips  \
# 0         76.6         78.9         80.6         82.7         85.5   1001
# 1         74.5         78.1         81.8         85.1         87.9   1003
# 2         57.2         60.4         60.5         64.6         64.6   1005
# 3         62.0         66.1         69.2         76.1         74.6   1007
# 4         65.8         68.5         73.0         79.6         81.0   1009
#
#    pct_college_2017  pct_college_2018  pct_college_2019  pct_college_2020  \
# 0              14.5              15.9              16.1              16.7
# 1              20.4              20.7              21.0              20.2
# 2               7.6               7.8               7.6               7.3
# 3               8.1               7.6               6.5               7.4
# 4               8.7               8.1               8.6               8.9
#
#    ...  pct_it_workers_2017  pct_it_workers_2018  pct_it_workers_2019  \
# ...

# %%
train[train['year'] == 2022]
# Out:
#                   row_id  cfips          county    state  \
# 29       1001_2022-01-01   1001  Autauga County  Alabama
# 30       1001_2022-02-01   1001  Autauga County  Alabama
# 31       1001_2022-03-01   1001  Autauga County  Alabama
# 32       1001_2022-04-01   1001  Autauga County  Alabama
# 33       1001_2022-05-01   1001  Autauga County  Alabama
# ...                  ...    ...             ...      ...
# 122260  56045_2022-06-01  56045   Weston County  Wyoming
# 122261  56045_2022-07-01  56045   Weston County  Wyoming
# 122262  56045_2022-08-01  56045   Weston County  Wyoming
# 122263  56045_2022-09-01  56045   Weston County  Wyoming
# 122264  56045_2022-10-01  56045   Weston County  Wyoming
#
#         microbusiness_density  active  month  year
# 29                   3.296781    1401      1  2022
# 30                   3.334431    1417      2  2022
# 31                   3.336785    1418      3  2022
# 32                   3.372082    1433      4  2022
# ...
